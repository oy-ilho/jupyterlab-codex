# %%
raise ValueError("synthetic traceback for tail truncation test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 raise ValueError("synthetic traceback for tail truncation test")
#
# ValueError: synthetic traceback for tail truncation test
